# %% [markdown]
# # Molecular Simulation

# %% [markdown]
# Source code: https://www.youtube.com/watch?v=Aez8zNqRKHM&list=PLXCw5VdOQb7iMIWV1HHfy-fzKIWtp78eX&index=2&ab_channel=room333
# Personal reference: https://youtu.be/Aez8zNqRKHM?t=621

# %% [markdown]
# ## 1) Import Essentials

# %%
import numpy as np
from matplotlib import pyplot as plt
import math

# %% [markdown]
# ## 2) Initialize init, position, and velocity of particles

# %%
class Dynamics:
    def __init__(self):
        self.dim = 2 #dimensions
        self.num = 60 #number of particles
        self.box_len = 12
        self.mass = 1 #mass of particles
        self.temp = 300
        self.k = 1
        self.positions = np.zeros((self.num, self.dim)) #particles begin at position zero
        self.velocities = np.zeros((self.num, self.dim))
    #fx for position
    def position_particles(self):
        self.positions = np.random.random_sample((self.num, self.dim))*self.box_len #random positons for the different particles, range from 0-12
    #fx for velocity
    def velocity_particles(self):
        #minimization - gaps between particles
        std_dev = (self.mass/(self.k*self.temp))**.5
        self.velocities = np.random.normal(loc=0,scale =std_dev,size=(self.num,self.dim))

# %% [markdown]
# Maxwell-Boltzamn Distribution 1D
#
# - tells us about distribution of sppeds for gas particles at certain temperature.
#
# ![image.png](attachment:image.png)
# Credit: Wikipedia

# %% [markdown]
# Probability density Gaussian distribution
# ![image.png](attachment:image.png)
# - in this context, it is a bell curve that shows us probability of gas particles that move at certain speeds at certain temperature.

# %% [markdown]
# When relating the two functions, we can find that -
#
# ![image.png](attachment:image.png)
# Credit: room333

# %% [markdown]
# ## 3) Print out array of molecules' positions and velocities

# %%
#define functions to variable
mol_dynamics = Dynamics()

mol_dynamics.position_particles()
mol_dynamics.velocity_particles()

# %%
print(mol_dynamics.positions)#prints positions for all 55 particles
# Out:
# [[10.721975    9.75020318]
#  [ 1.92212399  2.37230591]
#  [ 0.6120607   9.02091464]
#  [ 3.27801767  4.92956832]
#  [ 8.5097997   2.4088826 ]
#  [ 1.66630051 10.95277997]
#  [ 5.10114945  3.37955325]
#  [11.50736904  4.98304491]
#  [ 3.68323731  8.09796272]
#  [ 1.42281128  2.49146186]
#  [ 2.53887539  1.11117164]
#  [11.60866366  6.42789742]
#  [ 6.18081992  2.54221766]
#  [ 4.81850841  9.65374582]
#  [ 9.09449824  7.103974  ]
#  [10.42615633  1.30875463]
#  [ 6.87191347 11.52803633]
#  [10.60225281 10.28633103]
#  [ 1.50939381  6.43843736]
#  [ 6.48185779  5.33194853]
#  [ 4.19788105  7.07839812]
#  [ 9.13103617  8.04763118]
#  [ 1.10990658  1.01828285]
#  [ 1.65321518  0.27318231]
#  [ 9.84629861  2.47141494]
#  [ 0.91778635  0.28449878]
#  [ 5.91196617  8.07970779]
#  [ 2.63943681 11.35736897]
#  [10.50743813 10.31692434]
#  [10.98087409  2.97671441]
#  [ 1.27199861  0.7302831 ]
#  [ 9.3885604   6.58976208]
#  [ 2.34142788  2.89319647]
#  [ 2.15284874  6.42265921]
#  [11.07054105  8.75868646]
#  [ 0.86911616  3.449915  ]
#  [ 9.8395149   9.69131451]
#  [11.54215883  1.72343078]
#  [ 6.97574454  0.10399931]
#  [ 3.32013253  5.1827387 ]
#  [ 8.77068797  4.30280206]
#  [ 0.61847977 11.60348275]
#  [ 8.50614515  5.66739655]
#  [11.72113534  6.39446422]
#  [ 8.08583156  2.7506142 ]
#  [10.94141501  2.15884907]
#  [ 1.22793399 10.36302795]
#  [ 2.79924389  2.05691353]
#  [11.05663781 11.05415463]
#  [11.12241534  4.01010573]
#  [10.51968074  7.11562007]
#  [ 5.84435352  3.94008734]
#  [ 9.42733244  4.31934569]
#  [10.23341382  4.52846497]
#  [ 9.0544427  11.32602152]
#  [ 5.1078434   7.39941145]
#  [ 0.69036441 10.67044129]
#  [ 3.14862854  9.2809204 ]
#  [ 9.01114188  0.03336602]
#  [ 4.29971328  0.07207297]]

# %%
print(mol_dynamics.velocities)#prints velocities for all 55 particles
# Out:
# [[-0.01580175 -0.06510191]
#  [-0.06274688 -0.04604436]
#  [ 0.04408481  0.02218738]
#  [-0.08170173  0.019313  ]
#  [ 0.04651108  0.01176375]
#  [-0.0744227   0.04781029]
#  [-0.09952809 -0.02905232]
#  [-0.13444214  0.02660302]
#  [ 0.07560445 -0.07242816]
#  [-0.0298995   0.00065333]
#  [-0.02051046 -0.04893813]
#  [-0.00839274  0.04052209]
#  [-0.03968357 -0.00286102]
#  [ 0.05278889  0.05120912]
#  [-0.08878855  0.0336109 ]
#  [-0.03838677  0.05125477]
#  [-0.12104754 -0.00117874]
#  [-0.09311716  0.04380808]
#  [-0.04407956  0.0042831 ]
#  [-0.01153197 -0.04170114]
#  [ 0.06165677  0.02292503]
#  [ 0.1133879  -0.04529904]
#  [ 0.13420418  0.10480178]
#  [ 0.06885445  0.07210738]
#  [-0.02216141  0.07672204]
#  [ 0.04122569 -0.00446504]
#  [-0.05687283 -0.01738785]
#  [ 0.05742888 -0.00596991]
#  [ 0.03853339  0.06290907]
#  [ 0.03478756 -0.0183675 ]
#  [-0.01990705  0.07221893]
#  [-0.0202654   0.04284883]
#  [ 0.06813595 -0.02474518]
#  [ 0.05484363  0.03392041]
#  [ 0.06650198  0.08211949]
#  [ 0.05073205 -0.070923  ]
#  [-0.1034685   0.00761273]
#  [-0.01695043 -0.05126622]
#  [ 0.01369968  0.02760328]
#  [-0.00359138  0.03933617]
#  [-0.01877661 -0.01328927]
#  [ 0.0418672  -0.05020823]
#  [ 0.07362114  0.01217984]
#  [ 0.01746702 -0.03923952]
#  [-0.05715473 -0.06322352]
#  [-0.02434341  0.0040669 ]
#  [-0.010508   -0.12636573]
#  [-0.03262451  0.07029685]
#  [-0.0783602  -0.00509797]
#  [ 0.01656743 -0.02410068]
#  [ 0.05343159  0.07173873]
#  [ 0.04647149  0.01894802]
#  [ 0.02180794  0.11315933]
#  [-0.02955494  0.05665566]
#  [-0.06466498  0.03475041]
#  [-0.03143879  0.08178828]
#  [ 0.05249027  0.07791989]
#  [-0.00712399 -0.0471584 ]
#  [-0.05002904 -0.06045738]
#  [-0.01799587 -0.16059394]]

# %%
mol_dynamics.draw_particles()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 mol_dynamics.draw_particles()
#
# AttributeError: 'Dynamics' object has no attribute 'draw_particles'
